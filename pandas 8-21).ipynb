# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# # Series operations

# %%
data=pd.read_csv("matches - matches.csv")
data
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
# here show frequency of every einner team using this(.value_counts())
a=data['winner'].value_counts()
a
# Out:
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: winner, dtype: int64

# %%
a.shape
# Out:
# (14,)

# %%
a.index
# Out:
# Index(['Mumbai Indians', 'Chennai Super Kings', 'Kolkata Knight Riders',
#        'Royal Challengers Bangalore', 'Kings XI Punjab', 'Rajasthan Royals',
#        'Delhi Daredevils', 'Sunrisers Hyderabad', 'Deccan Chargers',
#        'Gujarat Lions', 'Pune Warriors', 'Rising Pune Supergiant',
#        'Kochi Tuskers Kerala', 'Rising Pune Supergiants'],
#       dtype='object')

# %%
a.values
# Out:
# array([92, 79, 77, 73, 70, 63, 62, 42, 29, 13, 12, 10,  6,  5],
#       dtype=int64)

# %%
a.head()
# Out:
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Name: winner, dtype: int64

# %%
a.tail()
# Out:
# Gujarat Lions              13
# Pune Warriors              12
# Rising Pune Supergiant     10
# Kochi Tuskers Kerala        6
# Rising Pune Supergiants     5
# Name: winner, dtype: int64

# %%
a.head(10)
# Out:
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Name: winner, dtype: int64

# %%
#show index value
a['Deccan Chargers']
# Out:
# 29

# %%
data['team1'].value_counts()+data['team2'].value_counts()
# Out:
# Chennai Super Kings            131
# Deccan Chargers                 75
# Delhi Daredevils               147
# Gujarat Lions                   30
# Kings XI Punjab                148
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          148
# Mumbai Indians                 157
# Pune Warriors                   46
# Rajasthan Royals               118
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    152
# Sunrisers Hyderabad             76
# dtype: int64

# %% [markdown]
# # some of two teams having same index value

# %%
data['team1'].value_counts()-data['team2'].value_counts()
# Out:
# Chennai Super Kings            23
# Deccan Chargers                11
# Delhi Daredevils              -21
# Gujarat Lions                  -2
# Kings XI Punjab                 6
# Kochi Tuskers Kerala            0
# Kolkata Knight Riders         -12
# Mumbai Indians                  7
# Pune Warriors                  -6
# Rajasthan Royals              -10
# Rising Pune Supergiant          0
# Rising Pune Supergiants         0
# Royal Challengers Bangalore   -12
# Sunrisers Hyderabad            16
# dtype: int64

# %%
data['team1'].value_counts()*data['team2'].value_counts()
# Out:
# Chennai Super Kings            4158
# Deccan Chargers                1376
# Delhi Daredevils               5292
# Gujarat Lions                   224
# Kings XI Punjab                5467
# Kochi Tuskers Kerala             49
# Kolkata Knight Riders          5440
# Mumbai Indians                 6150
# Pune Warriors                   520
# Rajasthan Royals               3456
# Rising Pune Supergiant           64
# Rising Pune Supergiants          49
# Royal Challengers Bangalore    5740
# Sunrisers Hyderabad            1380
# dtype: int64

# %% [markdown]
# # Sort_values()

# %%
(data['team1'].value_counts()).sort_values()
# Out:
# Kochi Tuskers Kerala            7
# Rising Pune Supergiants         7
# Rising Pune Supergiant          8
# Gujarat Lions                  14
# Pune Warriors                  20
# Deccan Chargers                43
# Sunrisers Hyderabad            46
# Rajasthan Royals               54
# Delhi Daredevils               63
# Kolkata Knight Riders          68
# Royal Challengers Bangalore    70
# Kings XI Punjab                77
# Chennai Super Kings            77
# Mumbai Indians                 82
# Name: team1, dtype: int64

# %%
(data['team1'].value_counts()+data['team2'].value_counts()).sort_values()
# Out:
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Rising Pune Supergiant          16
# Gujarat Lions                   30
# Pune Warriors                   46
# Deccan Chargers                 75
# Sunrisers Hyderabad             76
# Rajasthan Royals               118
# Chennai Super Kings            131
# Delhi Daredevils               147
# Kings XI Punjab                148
# Kolkata Knight Riders          148
# Royal Challengers Bangalore    152
# Mumbai Indians                 157
# dtype: int64

# %%
data.sort_values("date")
# Out:
#     id  season        city        date                        team1  \
# 59  60    2008   Bangalore  2008-04-18        Kolkata Knight Riders
# 61  62    2008       Delhi  2008-04-19             Rajasthan Royals
# 60  61    2008  Chandigarh  2008-04-19          Chennai Super Kings
# 63  64    2008     Kolkata  2008-04-20              Deccan Chargers
# 62  63    2008      Mumbai  2008-04-20               Mumbai Indians
# ..  ..     ...         ...         ...                          ...
# 54  55    2017       Delhi  2017-05-14  Royal Challengers Bangalore
# 55  56    2017      Mumbai  2017-05-16       Rising Pune Supergiant
# 56  57    2017   Bangalore  2017-05-17          Sunrisers Hyderabad
# 57  58    2017   Bangalore  2017-05-19        Kolkata Knight Riders
# 58  59    2017   Hyderabad  2017-05-21               Mumbai Indians
#
#                           team2                  toss_winner toss_decision  \
# ...

# %%
data.sort_values("city")
# Out:
#       id  season       city        date                        team1  \
# 460  461    2014  Abu Dhabi  2014-04-18          Sunrisers Hyderabad
# 471  472    2014  Abu Dhabi  2014-04-26              Kings XI Punjab
# 470  471    2014  Abu Dhabi  2014-04-26  Royal Challengers Bangalore
# 464  465    2014  Abu Dhabi  2014-04-21          Chennai Super Kings
# 459  460    2014  Abu Dhabi  2014-04-18          Chennai Super Kings
# ..   ...     ...        ...         ...                          ...
# 466  467    2014        NaN  2014-04-23          Chennai Super Kings
# 468  469    2014        NaN  2014-04-25          Sunrisers Hyderabad
# 469  470    2014        NaN  2014-04-25               Mumbai Indians
# 474  475    2014        NaN  2014-04-28  Royal Challengers Bangalore
# 476  477    2014        NaN  2014-04-30          Sunrisers Hyderabad
#
#                      team2            toss_winner toss_decision  result  \
# ...

# %%
 #data.sort_values(['city', 'date'], inplace=True)    #still unsorted date

# %%
# data.sort_values(['city', 'date'], ascending=[True, False])

# %% [markdown]
# # drop_duplicates()

# %%
data.drop_duplicates(subset=["city"])
# Out:
#       id  season            city        date                        team1  \
# 0      1    2017       Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017            Pune  2017-04-06               Mumbai Indians
# 2      3    2017          Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017          Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017       Bangalore  2017-04-08  Royal Challengers Bangalore
# 6      7    2017          Mumbai  2017-04-09        Kolkata Knight Riders
# 10    11    2017         Kolkata  2017-04-13              Kings XI Punjab
# 14    15    2017           Delhi  2017-04-15             Delhi Daredevils
# 31    32    2017      Chandigarh  2017-04-28          Sunrisers Hyderabad
# 48    49    2017          Kanpur  2017-05-10                Gujarat Lions
# 64    65    2008          Jaipur  2008-04-21              Kings XI Punjab
# 66    67    2008         Chennai  2008-04-23          Chennai Super Kings
# ...

# %%
data.drop_duplicates(subset=["city"]).shape
# Out:
# (31, 18)

# %%
data.drop_duplicates(subset=["city"],inplace=True)

# %%
data.drop_duplicates('season',keep ='last')[['season','winner']]
# Out:
#      season                       winner
# 48     2017             Delhi Daredevils
# 66     2008          Chennai Super Kings
# 160    2009              Kings XI Punjab
# 224    2010              Deccan Chargers
# 236    2011  Royal Challengers Bangalore
# 312    2012          Chennai Super Kings
# 440    2013        Kolkata Knight Riders
# 461    2014  Royal Challengers Bangalore

# %%
data.drop_duplicates('season',keep ='last')[['season','winner']].sort_values('season')
# Out:
#      season                       winner
# 66     2008          Chennai Super Kings
# 160    2009              Kings XI Punjab
# 224    2010              Deccan Chargers
# 236    2011  Royal Challengers Bangalore
# 312    2012          Chennai Super Kings
# 440    2013        Kolkata Knight Riders
# 461    2014  Royal Challengers Bangalore
# 48     2017             Delhi Daredevils

# %%
len(data)
# Out:
# 31

# %% [markdown]
# # groupby()

# %%
a=data.groupby('city')
a

# %%
len(a)
# Out:
# 30

# %%
a.size()
# Out:
# city
# Abu Dhabi         1
# Ahmedabad         1
# Bangalore         1
# Bloemfontein      1
# Cape Town         1
# Centurion         1
# Chandigarh        1
# Chennai           1
# Cuttack           1
# Delhi             1
# Dharamsala        1
# Durban            1
# East London       1
# Hyderabad         1
# Indore            1
# Jaipur            1
# Johannesburg      1
# Kanpur            1
# Kimberley         1
# Kochi             1
# Kolkata           1
# Mumbai            1
# Nagpur            1
# Port Elizabeth    1
# Pune              1
# Raipur            1
# Rajkot            1
# Ranchi            1
# Sharjah           1
# Visakhapatnam     1
# dtype: int64

# %%
a.size().sort_values(ascending=True)
# Out:
# city
# Abu Dhabi         1
# Ranchi            1
# Rajkot            1
# Raipur            1
# Pune              1
# Port Elizabeth    1
# Nagpur            1
# Mumbai            1
# Kolkata           1
# Kochi             1
# Kimberley         1
# Kanpur            1
# Johannesburg      1
# Jaipur            1
# Indore            1
# Hyderabad         1
# East London       1
# Durban            1
# Dharamsala        1
# Delhi             1
# Cuttack           1
# Chennai           1
# Chandigarh        1
# Centurion         1
# Cape Town         1
# Bloemfontein      1
# Bangalore         1
# Ahmedabad         1
# Sharjah           1
# Visakhapatnam     1
# dtype: int64

# %%
a.first()
# Out:
#                  id  season        date                        team1  \
# city
# Abu Dhabi       458    2014  2014-04-16        Kolkata Knight Riders
# Ahmedabad       180    2010  2010-03-15             Rajasthan Royals
# Bangalore         5    2017  2017-04-08  Royal Challengers Bangalore
# Bloemfontein    161    2009  2009-05-15             Delhi Daredevils
# Cape Town       118    2009  2009-04-18               Mumbai Indians
# Centurion       133    2009  2009-04-28             Delhi Daredevils
# Chandigarh       32    2017  2017-04-28          Sunrisers Hyderabad
# Chennai          67    2008  2008-04-23          Chennai Super Kings
# Cuttack         186    2010  2010-03-19              Deccan Chargers
# Delhi            15    2017  2017-04-15             Delhi Daredevils
# Dharamsala      225    2010  2010-04-16              Kings XI Punjab
# Durban          123    2009  2009-04-21              Kings XI Punjab
# ...

# %%
a.last()
# Out:
#                  id  season        date                        team1  \
# city
# Abu Dhabi       458    2014  2014-04-16        Kolkata Knight Riders
# Ahmedabad       180    2010  2010-03-15             Rajasthan Royals
# Bangalore         5    2017  2017-04-08  Royal Challengers Bangalore
# Bloemfontein    161    2009  2009-05-15             Delhi Daredevils
# Cape Town       118    2009  2009-04-18               Mumbai Indians
# Centurion       133    2009  2009-04-28             Delhi Daredevils
# Chandigarh       32    2017  2017-04-28          Sunrisers Hyderabad
# Chennai          67    2008  2008-04-23          Chennai Super Kings
# Cuttack         186    2010  2010-03-19              Deccan Chargers
# Delhi            15    2017  2017-04-15             Delhi Daredevils
# Dharamsala      225    2010  2010-04-16              Kings XI Punjab
# Durban          123    2009  2009-04-21              Kings XI Punjab
# ...

# %%
a.groups
# Out:
# {'Abu Dhabi': [457], 'Ahmedabad': [179], 'Bangalore': [4], 'Bloemfontein': [160], 'Cape Town': [117], 'Centurion': [132], 'Chandigarh': [31], 'Chennai': [66], 'Cuttack': [185], 'Delhi': [14], 'Dharamsala': [224], 'Durban': [122], 'East London': [137], 'Hyderabad': [0], 'Indore': [3], 'Jaipur': [64], 'Johannesburg': [140], 'Kanpur': [48], 'Kimberley': [150], 'Kochi': [236], 'Kolkata': [10], 'Mumbai': [6], 'Nagpur': [209], 'Port Elizabeth': [121], 'Pune': [1], 'Raipur': [418], 'Rajkot': [2], 'Ranchi': [440], 'Sharjah': [458], 'Visakhapatnam': [312]}

# %%
a.sum()
a.mean()
# Out:
# C:\Users\Arooj\AppData\Local\Temp\ipykernel_13452\3232306174.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   a.sum()
# C:\Users\Arooj\AppData\Local\Temp\ipykernel_13452\3232306174.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   a.mean()
#                    id  season  dl_applied  win_by_runs  win_by_wickets  \
# city
# Abu Dhabi       458.0  2014.0         0.0         41.0             0.0
# Ahmedabad       180.0  2010.0         0.0          0.0             6.0
# Bangalore         5.0  2017.0         0.0         15.0             0.0
# ...

# %%
a["season"].mean()
# Out:
# city
# Abu Dhabi         2014.0
# Ahmedabad         2010.0
# Bangalore         2017.0
# Bloemfontein      2009.0
# Cape Town         2009.0
# Centurion         2009.0
# Chandigarh        2017.0
# Chennai           2008.0
# Cuttack           2010.0
# Delhi             2017.0
# Dharamsala        2010.0
# Durban            2009.0
# East London       2009.0
# Hyderabad         2017.0
# Indore            2017.0
# Jaipur            2008.0
# Johannesburg      2009.0
# Kanpur            2017.0
# Kimberley         2009.0
# Kochi             2011.0
# Kolkata           2017.0
# Mumbai            2017.0
# Nagpur            2010.0
# Port Elizabeth    2009.0
# Pune              2017.0
# Raipur            2013.0
# Rajkot            2017.0
# Ranchi            2013.0
# Sharjah           2014.0
# Visakhapatnam     2012.0
# Name: season, dtype: float64

# %%
a["season"].mean().sort_values(ascending=True)      #True for ascending
# Out:
# city
# Jaipur            2008.0
# Chennai           2008.0
# Kimberley         2009.0
# Bloemfontein      2009.0
# Cape Town         2009.0
# Centurion         2009.0
# East London       2009.0
# Johannesburg      2009.0
# Port Elizabeth    2009.0
# Durban            2009.0
# Nagpur            2010.0
# Cuttack           2010.0
# Ahmedabad         2010.0
# Dharamsala        2010.0
# Kochi             2011.0
# Visakhapatnam     2012.0
# Raipur            2013.0
# Ranchi            2013.0
# Abu Dhabi         2014.0
# Sharjah           2014.0
# Kolkata           2017.0
# Mumbai            2017.0
# Hyderabad         2017.0
# Delhi             2017.0
# Pune              2017.0
# Chandigarh        2017.0
# Rajkot            2017.0
# Bangalore         2017.0
# Kanpur            2017.0
# Indore            2017.0
# Name: season, dtype: float64

# %%
a["season"].mean().sort_values(ascending=False)      #False for descending
# Out:
# city
# Indore            2017.0
# Bangalore         2017.0
# Rajkot            2017.0
# Chandigarh        2017.0
# Pune              2017.0
# Delhi             2017.0
# Mumbai            2017.0
# Kolkata           2017.0
# Kanpur            2017.0
# Hyderabad         2017.0
# Abu Dhabi         2014.0
# Sharjah           2014.0
# Ranchi            2013.0
# Raipur            2013.0
# Visakhapatnam     2012.0
# Kochi             2011.0
# Ahmedabad         2010.0
# Dharamsala        2010.0
# Nagpur            2010.0
# Cuttack           2010.0
# Johannesburg      2009.0
# East London       2009.0
# Kimberley         2009.0
# Durban            2009.0
# Port Elizabeth    2009.0
# Centurion         2009.0
# Cape Town         2009.0
# Bloemfontein      2009.0
# Chennai           2008.0
# Jaipur            2008.0
# Name: season, dtype: float64

# %%
a["season"].mean().sort_values(ascending=False).head(5)
# Out:
# city
# Indore        2017.0
# Bangalore     2017.0
# Rajkot        2017.0
# Chandigarh    2017.0
# Pune          2017.0
# Name: season, dtype: float64

# %% [markdown]
# # Import new file here

# %%
data2=pd.read_csv("deliveries.csv")
data2
# Out:
#      match_id  inning                 batting_team  \
# 0           1       1          Sunrisers Hyderabad
# 1           1       1          Sunrisers Hyderabad
# 2           1       1          Sunrisers Hyderabad
# 3           1       1          Sunrisers Hyderabad
# 4           1       1          Sunrisers Hyderabad
# ..        ...     ...                          ...
# 993         5       1  Royal Challengers Bangalore
# 994         5       1  Royal Challengers Bangalore
# 995         5       1  Royal Challengers Bangalore
# 996         5       1  Royal Challengers Bangalore
# 997         5       1  Royal Challengers Bangalore
#
#                     bowling_team  over  ball        batsman non_striker  \
# 0    Royal Challengers Bangalore     1     1      DA Warner    S Dhawan
# 1    Royal Challengers Bangalore     1     2      DA Warner    S Dhawan
# 2    Royal Challengers Bangalore     1     3      DA Warner    S Dhawan
# ...

# %% [markdown]
# # Which player has scored the most sixes?

# %%
mask=data2['batsman_runs']==6
new_delivery=data2[mask]

# %%
new_delivery.shape
# Out:
# (64, 18)

# %%
new_delivery.shape[0]
# Out:
# 64

# %%
new_delivery.groupby('batsman')['batsman_runs'].count()
# Out:
# batsman
# A Choudhary     1
# AJ Finch        2
# AM Rahane       4
# AR Patel        1
# BA Stokes       3
# BB McCullum     2
# BCJ Cutting     2
# CA Lynn         8
# CH Gayle        3
# DA Miller       2
# DA Warner       1
# DJ Hooda        1
# DT Christian    1
# GJ Maxwell      4
# HH Pandya       4
# HM Amla         1
# JC Buttler      3
# KA Pollard      1
# KD Karthik      2
# KM Jadhav       1
# M Vohra         1
# MC Henriques    2
# MK Tiwary       2
# N Rana          2
# SPD Smith       3
# SR Watson       1
# STR Binny       1
# TG Southee      1
# TS Mills        1
# Yuvraj Singh    3
# Name: batsman_runs, dtype: int64

# %%
new_delivery['batsman_runs'].sum()
# Out:
# 384

# %%
new_delivery['batsman_runs'].head()
# Out:
# 10    6
# 47    6
# 75    6
# 89    6
# 91    6
# Name: batsman_runs, dtype: int64

# %%
new_delivery.groupby('batsman')['batsman_runs'].count().sort_values(ascending=False).head(5)
# Out:
# batsman
# CA Lynn         8
# GJ Maxwell      4
# AM Rahane       4
# HH Pandya       4
# Yuvraj Singh    3
# Name: batsman_runs, dtype: int64

# %% [markdown]
# # Which player has scored the most 4?

# %%
mask=data2['batsman_runs']==4
new_delivery=data2[mask]

# %%
new_delivery.shape
# Out:
# (130, 18)

# %%
new_delivery.shape[0]
# Out:
# 130

# %%
new_delivery.groupby('batsman')['batsman_runs'].count().sort_values(ascending=False).head(5)
# Out:
# batsman
# G Gambhir        12
# SPD Smith        10
# Mandeep Singh     8
# AM Rahane         7
# SK Raina          7
# Name: batsman_runs, dtype: int64

# %% [markdown]
# # Against which three teams did 'CA Lynn' score more runs?

# %%
v=data2[data2['batsman']=='CA Lynn']
v.groupby('bowling_team')['batsman_runs'].sum()
# Out:
# bowling_team
# Gujarat Lions    93
# Name: batsman_runs, dtype: int64

# %%
v.groupby('bowling_team')['batsman_runs'].sum().sort_values(ascending=False).head().index[0]
# Out:
# 'Gujarat Lions'

# %%
def run_scored(batsman_name):
    v=data2[data2['batsman']=='batsman_name']
    return v.groupby('bowling_team')['batsman_runs'].sum()

# %%
 run_scored("PJ Cummins")
# Out:
# Series([], Name: batsman_runs, dtype: int64)

# %% [markdown]
# # merge function()

# %%
data2.merge(data,left_on = 'match_id',right_on = 'id')
# Out:
#      match_id  inning                 batting_team  \
# 0           1       1          Sunrisers Hyderabad
# 1           1       1          Sunrisers Hyderabad
# 2           1       1          Sunrisers Hyderabad
# 3           1       1          Sunrisers Hyderabad
# 4           1       1          Sunrisers Hyderabad
# ..        ...     ...                          ...
# 993         5       1  Royal Challengers Bangalore
# 994         5       1  Royal Challengers Bangalore
# 995         5       1  Royal Challengers Bangalore
# 996         5       1  Royal Challengers Bangalore
# 997         5       1  Royal Challengers Bangalore
#
#                     bowling_team  over  ball        batsman non_striker  \
# 0    Royal Challengers Bangalore     1     1      DA Warner    S Dhawan
# 1    Royal Challengers Bangalore     1     2      DA Warner    S Dhawan
# 2    Royal Challengers Bangalore     1     3      DA Warner    S Dhawan
# ...

# %%
data2.merge(data,left_on = 'match_id',right_on = 'id').shape
# Out:
# (998, 36)

# %%
print(data2.shape)
# Out:
# (998, 18)

# %%
print(data.shape)
# Out:
# (31, 18)

# %%
new_datasets=data2.merge(data,left_on = 'match_id',right_on = 'id')
new_datasets.shape
# Out:
# (998, 36)

# %%
new_datasets.groupby('batsman')['batsman_runs'].sum()
# Out:
# batsman
# A Choudhary        6
# AJ Finch          15
# AM Rahane         79
# AR Patel          24
# AT Rayudu         10
# BA Stokes         71
# BB McCullum       35
# BCJ Cutting       16
# CA Lynn           93
# CH Gayle          38
# DA Miller         30
# DA Warner         14
# DJ Hooda          16
# DT Christian      17
# G Gambhir         76
# GJ Maxwell        44
# HH Pandya         35
# HM Amla           28
# JC Buttler        38
# JJ Roy            14
# KA Pollard        27
# KD Karthik        47
# KH Pandya          3
# KM Jadhav         31
# M Vohra           14
# MA Agarwal         6
# MC Henriques      52
# MK Tiwary         40
# MS Dhoni          17
# Mandeep Singh     36
# N Rana            34
# PA Patel          19
# RG Sharma          3
# S Aravind          0
# S Dhawan          40
# SK Raina          68
# SPD Smith        110
# SR Watson         42
# STR Binny         11
# Sachin Baby        1
# TG Southee         7
# TM Head           30
# TS Mills           6
# ...

# %% [markdown]
# # convert series into dataframes by using reset_index()

# %%
new_datasets.groupby(['batsman','season'])['batsman_runs'].sum()
# Out:
# batsman        season
# A Choudhary    2017        6
# AJ Finch       2017       15
# AM Rahane      2017       79
# AR Patel       2017       24
# AT Rayudu      2017       10
# BA Stokes      2017       71
# BB McCullum    2017       35
# BCJ Cutting    2017       16
# CA Lynn        2017       93
# CH Gayle       2017       38
# DA Miller      2017       30
# DA Warner      2017       14
# DJ Hooda       2017       16
# DT Christian   2017       17
# G Gambhir      2017       76
# GJ Maxwell     2017       44
# HH Pandya      2017       35
# HM Amla        2017       28
# JC Buttler     2017       38
# JJ Roy         2017       14
# KA Pollard     2017       27
# KD Karthik     2017       47
# KH Pandya      2017        3
# KM Jadhav      2017       31
# M Vohra        2017       14
# MA Agarwal     2017        6
# MC Henriques   2017       52
# MK Tiwary      2017       40
# MS Dhoni       2017       17
# Mandeep Singh  2017       36
# N Rana         2017       34
# ...

# %%
new_datasets.groupby(['batsman','season'])['batsman_runs'].sum().reset_index()
# Out:
#           batsman  season  batsman_runs
# 0     A Choudhary    2017             6
# 1        AJ Finch    2017            15
# 2       AM Rahane    2017            79
# 3        AR Patel    2017            24
# 4       AT Rayudu    2017            10
# 5       BA Stokes    2017            71
# 6     BB McCullum    2017            35
# 7     BCJ Cutting    2017            16
# 8         CA Lynn    2017            93
# 9        CH Gayle    2017            38
# 10      DA Miller    2017            30
# 11      DA Warner    2017            14
# 12       DJ Hooda    2017            16
# 13   DT Christian    2017            17
# 14      G Gambhir    2017            76
# 15     GJ Maxwell    2017            44
# 16      HH Pandya    2017            35
# 17        HM Amla    2017            28
# 18     JC Buttler    2017            38
# 19         JJ Roy    2017            14
# 20     KA Pollard    2017            27
# 21     KD Karthik    2017            47
# ...

# %%
new_datasets.groupby(['batsman','season'])['batsman_runs'].sum().sort_values(ascending=False).reset_index()
# Out:
#           batsman  season  batsman_runs
# 0       SPD Smith    2017           110
# 1         CA Lynn    2017            93
# 2       AM Rahane    2017            79
# 3       G Gambhir    2017            76
# 4       BA Stokes    2017            71
# 5        SK Raina    2017            68
# 6    Yuvraj Singh    2017            62
# 7    MC Henriques    2017            52
# 8      KD Karthik    2017            47
# 9      GJ Maxwell    2017            44
# 10      SR Watson    2017            42
# 11      MK Tiwary    2017            40
# 12       S Dhawan    2017            40
# 13       CH Gayle    2017            38
# 14     JC Buttler    2017            38
# 15  Mandeep Singh    2017            36
# 16      HH Pandya    2017            35
# 17    BB McCullum    2017            35
# 18         N Rana    2017            34
# 19      KM Jadhav    2017            31
# 20      DA Miller    2017            30
# 21        TM Head    2017            30
# ...

# %%
new_datasets.groupby(['batsman','season'])['batsman_runs'].sum().sort_values(ascending=False).reset_index().drop_duplicates(subset='batsman_runs', keep='first')
# Out:
#           batsman  season  batsman_runs
# 0       SPD Smith    2017           110
# 1         CA Lynn    2017            93
# 2       AM Rahane    2017            79
# 3       G Gambhir    2017            76
# 4       BA Stokes    2017            71
# 5        SK Raina    2017            68
# 6    Yuvraj Singh    2017            62
# 7    MC Henriques    2017            52
# 8      KD Karthik    2017            47
# 9      GJ Maxwell    2017            44
# 10      SR Watson    2017            42
# 11      MK Tiwary    2017            40
# 13       CH Gayle    2017            38
# 15  Mandeep Singh    2017            36
# 16      HH Pandya    2017            35
# 18         N Rana    2017            34
# 19      KM Jadhav    2017            31
# 20      DA Miller    2017            30
# 22        HM Amla    2017            28
# 23     KA Pollard    2017            27
# 24       AR Patel    2017            24
# 25       PA Patel    2017            19
# ...

# %%
new_datasets.groupby(['batsman','season'])['batsman_runs'].sum().sort_values(ascending=False).reset_index().drop_duplicates(subset='batsman_runs', keep='first').sort_values('batsman')
# Out:
#           batsman  season  batsman_runs
# 30       AJ Finch    2017            15
# 2       AM Rahane    2017            79
# 24       AR Patel    2017            24
# 36      AT Rayudu    2017            10
# 4       BA Stokes    2017            71
# 28    BCJ Cutting    2017            16
# 1         CA Lynn    2017            93
# 13       CH Gayle    2017            38
# 20      DA Miller    2017            30
# 31      DA Warner    2017            14
# 26   DT Christian    2017            17
# 3       G Gambhir    2017            76
# 9      GJ Maxwell    2017            44
# 16      HH Pandya    2017            35
# 22        HM Amla    2017            28
# 23     KA Pollard    2017            27
# 8      KD Karthik    2017            47
# 19      KM Jadhav    2017            31
# 7    MC Henriques    2017            52
# 11      MK Tiwary    2017            40
# 15  Mandeep Singh    2017            36
# 18         N Rana    2017            34
# ...

# %%
new_datasets.groupby(['batsman','season'])['batsman_runs'].sum().sort_values(ascending=False).reset_index().drop_duplicates(subset='batsman_runs', keep='first')[['season','batsman_runs']]
# Out:
#     season  batsman_runs
# 0     2017           110
# 1     2017            93
# 2     2017            79
# 3     2017            76
# 4     2017            71
# 5     2017            68
# 6     2017            62
# 7     2017            52
# 8     2017            47
# 9     2017            44
# 10    2017            42
# 11    2017            40
# 13    2017            38
# 15    2017            36
# 16    2017            35
# 18    2017            34
# 19    2017            31
# 20    2017            30
# 22    2017            28
# 23    2017            27
# 24    2017            24
# 25    2017            19
# 26    2017            17
# 28    2017            16
# 30    2017            15
# 31    2017            14
# 35    2017            11
# 36    2017            10
# 37    2017             7
# 38    2017             6
# 41    2017             3
# 44    2017             1
# 45    2017             0

# %% [markdown]
# # pandas pivot_table()

# %%
Dict={"spends":[11,222,33,44,56],
       "Name":["Fatima", "Arif", "Bilal", "Umara", "Sami" ],
      "city":['faisalabad','lahore','karachi','hydarabad','layyah'],
      "frequency":["daily","weekly","monthly","once","never"],
      "item":["buger","sandwish","pizza","paneer","fries"],
      "gender":["M","F","M","M","F"]
     }

# %%
result= pd.DataFrame(Dict)
print(result)
# Out:
#    spends    Name        city frequency      item gender
# 0      11  Fatima  faisalabad     daily     buger      M
# 1     222    Arif      lahore    weekly  sandwish      F
# 2      33   Bilal     karachi   monthly     pizza      M
# 3      44   Umara   hydarabad      once    paneer      M
# 4      56    Sami      layyah     never     fries      F

# %%
result.head()
# Out:
#    spends    Name        city frequency      item gender
# 0      11  Fatima  faisalabad     daily     buger      M
# 1     222    Arif      lahore    weekly  sandwish      F
# 2      33   Bilal     karachi   monthly     pizza      M
# 3      44   Umara   hydarabad      once    paneer      M
# 4      56    Sami      layyah     never     fries      F

# %%
result.pivot_table(index='city',columns='item',values='spends',aggfunc='mean')
# Out:
# item        buger  fries  paneer  pizza  sandwish
# city
# faisalabad   11.0    NaN     NaN    NaN       NaN
# hydarabad     NaN    NaN    44.0    NaN       NaN
# karachi       NaN    NaN     NaN   33.0       NaN
# lahore        NaN    NaN     NaN    NaN     222.0
# layyah        NaN   56.0     NaN    NaN       NaN

# %%
b=result.pivot_table(index=['city','gender'],columns='item',values='spends',aggfunc='mean')
b
# Out:
# item               buger  fries  paneer  pizza  sandwish
# city       gender
# faisalabad M        11.0    NaN     NaN    NaN       NaN
# hydarabad  M         NaN    NaN    44.0    NaN       NaN
# karachi    M         NaN    NaN     NaN   33.0       NaN
# lahore     F         NaN    NaN     NaN    NaN     222.0
# layyah     F         NaN   56.0     NaN    NaN       NaN

# %%
sns.heatmap(b)
# Out:
# <Axes: xlabel='item', ylabel='city-gender'>

# %%
data2.head()

# %%
data.head()

# %% [markdown]
# # now we create a pivot table

# %%
mask= data2['batsman_runs']==6
six=data2[mask]
six
# Out:
#      match_id  inning         batting_team                 bowling_team  over  \
# 10          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 47          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     8
# 75          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    13
# 89          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    15
# 91          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    15
# ..        ...     ...                  ...                          ...   ...
# 927         4       2      Kings XI Punjab       Rising Pune Supergiant    14
# 934         4       2      Kings XI Punjab       Rising Pune Supergiant    15
# 936         4       2      Kings XI Punjab       Rising Pune Supergiant    16
# 937         4       2      Kings XI Punjab       Rising Pune Supergiant    16
# 950         4       2      Kings XI Punjab       Rising Pune Supergiant    18
#
# ...

# %%
six.shape
# Out:
# (64, 18)

# %%
pt=six.pivot_table(index='over',columns='batting_team',values='batsman_runs',aggfunc='count')
pt
# Out:
# batting_team  Gujarat Lions  Kings XI Punjab  Kolkata Knight Riders  \
# over
# 2                       NaN              NaN                    1.0
# 3                       NaN              1.0                    1.0
# 4                       1.0              1.0                    NaN
# 6                       NaN              NaN                    NaN
# 7                       1.0              NaN                    3.0
# 8                       NaN              NaN                    NaN
# 9                       NaN              NaN                    NaN
# 10                      2.0              NaN                    NaN
# 11                      NaN              1.0                    NaN
# 13                      NaN              1.0                    NaN
# 14                      NaN              1.0                    1.0
# 15                      NaN              1.0                    2.0
# 16                      NaN              2.0                    NaN
# ...

# %% [markdown]
# # creat heatmap

# %%
import seaborn as sns

# %%
sns.heatmap(pt)
# Out:
# <Axes: xlabel='batting_team', ylabel='over'>

# %%
data.shape
# Out:
# (31, 18)

# %%
data.corr()
# Out:
# C:\Users\Arooj\AppData\Local\Temp\ipykernel_13452\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                       id    season  dl_applied  win_by_runs  win_by_wickets  \
# id              1.000000 -0.252048   -0.044248     0.033989        0.034646
# season         -0.252048  1.000000   -0.186099     0.006016        0.213082
# dl_applied     -0.044248 -0.186099    1.000000    -0.020579       -0.170988
# win_by_runs     0.033989  0.006016   -0.020579     1.000000       -0.561229
# win_by_wickets  0.034646  0.213082   -0.170988    -0.561229        1.000000
# umpire3              NaN       NaN         NaN          NaN             NaN
#
#                 umpire3
# id                  NaN
# season              NaN
# dl_applied          NaN
# win_by_runs         NaN
# ...

# %%
sns.heatmap(data.corr())
# Out:
# C:\Users\Arooj\AppData\Local\Temp\ipykernel_13452\1794321463.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr())
# <Axes: >

# %% [markdown]
# # the rename function

# %%
result
# Out:
#    spends    Name        city frequency      item gender
# 0      11  Fatima  faisalabad     daily     buger      M
# 1     222    Arif      lahore    weekly  sandwish      F
# 2      33   Bilal     karachi   monthly     pizza      M
# 3      44   Umara   hydarabad      once    paneer      M
# 4      56    Sami      layyah     never     fries      F

# %%
new=result.rename(columns={'spends':'budget','city':'place'})
new
# Out:
#    budget    Name       place frequency      item gender
# 0      11  Fatima  faisalabad     daily     buger      M
# 1     222    Arif      lahore    weekly  sandwish      F
# 2      33   Bilal     karachi   monthly     pizza      M
# 3      44   Umara   hydarabad      once    paneer      M
# 4      56    Sami      layyah     never     fries      F

# %% [markdown]
# # for permenent chnge

# %%
new.rename(columns={'spends':'budget','city':'place'},inplace=False)           # true not run??
# Out:
#    budget    Name       place frequency      item gender
# 0      11  Fatima  faisalabad     daily     buger      M
# 1     222    Arif      lahore    weekly  sandwish      F
# 2      33   Bilal     karachi   monthly     pizza      M
# 3      44   Umara   hydarabad      once    paneer      M
# 4      56    Sami      layyah     never     fries      F

# %% [markdown]
# # set index and reset_index()

# %%
# set_index(): convert column into index

# %%
data.head(2)
# Out:
#    id  season       city        date                team1  \
# 0   1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06       Mumbai Indians
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
#
#   player_of_match                                      venue         umpire1  \
# 0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal     AY Dandekar
# 1       SPD Smith    Maharashtra Cricket Association Stadium  A Nand Kishore
#
#     umpire2  umpire3
# 0  NJ Llong      NaN
# 1    S Ravi      NaN

# %%
data.set_index('id')       # here id column convert into index
# Out:
#      season            city        date                        team1  \
# id
# 1      2017       Hyderabad  2017-04-05          Sunrisers Hyderabad
# 2      2017            Pune  2017-04-06               Mumbai Indians
# 3      2017          Rajkot  2017-04-07                Gujarat Lions
# 4      2017          Indore  2017-04-08       Rising Pune Supergiant
# 5      2017       Bangalore  2017-04-08  Royal Challengers Bangalore
# 7      2017          Mumbai  2017-04-09        Kolkata Knight Riders
# 11     2017         Kolkata  2017-04-13              Kings XI Punjab
# 15     2017           Delhi  2017-04-15             Delhi Daredevils
# 32     2017      Chandigarh  2017-04-28          Sunrisers Hyderabad
# 49     2017          Kanpur  2017-05-10                Gujarat Lions
# 65     2008          Jaipur  2008-04-21              Kings XI Punjab
# 67     2008         Chennai  2008-04-23          Chennai Super Kings
# ...

# %%
data.set_index('season').head(3)
# Out:
#         id       city        date                team1  \
# season
# 2017     1  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 2017     2       Pune  2017-04-06       Mumbai Indians
# 2017     3     Rajkot  2017-04-07        Gujarat Lions
#
#                               team2                  toss_winner  \
# season
# 2017    Royal Challengers Bangalore  Royal Challengers Bangalore
# 2017         Rising Pune Supergiant       Rising Pune Supergiant
# 2017          Kolkata Knight Riders        Kolkata Knight Riders
#
#        toss_decision  result  dl_applied                  winner  win_by_runs  \
# season
# 2017           field  normal           0     Sunrisers Hyderabad           35
# 2017           field  normal           0  Rising Pune Supergiant            0
# 2017           field  normal           0   Kolkata Knight Riders            0
#
#         win_by_wickets player_of_match  \
# season
# 2017                 0    Yuvraj Singh
# 2017                 7       SPD Smith
# ...

# %%
#reset_index(): covert into dataframes

# %%
data['winner'].value_counts()
# Out:
# Kolkata Knight Riders          5
# Royal Challengers Bangalore    4
# Delhi Daredevils               4
# Chennai Super Kings            4
# Kings XI Punjab                3
# Mumbai Indians                 3
# Rajasthan Royals               3
# Sunrisers Hyderabad            2
# Deccan Chargers                2
# Rising Pune Supergiant         1
# Name: winner, dtype: int64

# %%
data['winner'].value_counts().reset_index()
# Out:
#                          index  winner
# 0        Kolkata Knight Riders       5
# 1  Royal Challengers Bangalore       4
# 2             Delhi Daredevils       4
# 3          Chennai Super Kings       4
# 4              Kings XI Punjab       3
# 5               Mumbai Indians       3
# 6             Rajasthan Royals       3
# 7          Sunrisers Hyderabad       2
# 8              Deccan Chargers       2
# 9       Rising Pune Supergiant       1

# %% [markdown]
# # dropna() method

# %%
data.head(2)
# Out:
#    id  season       city        date                team1  \
# 0   1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06       Mumbai Indians
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
#
#   player_of_match                                      venue         umpire1  \
# 0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal     AY Dandekar
# 1       SPD Smith    Maharashtra Cricket Association Stadium  A Nand Kishore
#
#     umpire2  umpire3
# 0  NJ Llong      NaN
# 1    S Ravi      NaN

# %%
data['date'].fillna(np.nan)
data
# Out:
#       id  season            city  date                        team1  \
# 0      1    2017       Hyderabad   NaN          Sunrisers Hyderabad
# 1      2    2017            Pune   NaN               Mumbai Indians
# 2      3    2017          Rajkot   NaN                Gujarat Lions
# 3      4    2017          Indore   NaN       Rising Pune Supergiant
# 4      5    2017       Bangalore   NaN  Royal Challengers Bangalore
# 6      7    2017          Mumbai   NaN        Kolkata Knight Riders
# 10    11    2017         Kolkata   NaN              Kings XI Punjab
# 14    15    2017           Delhi   NaN             Delhi Daredevils
# 31    32    2017      Chandigarh   NaN          Sunrisers Hyderabad
# 48    49    2017          Kanpur   NaN                Gujarat Lions
# 64    65    2008          Jaipur   NaN              Kings XI Punjab
# 66    67    2008         Chennai   NaN          Chennai Super Kings
# 117  118    2009       Cape Town   NaN               Mumbai Indians
# ...

# %%
data.dropna(how="all")
# Out:
#       id  season            city  date                        team1  \
# 0      1    2017       Hyderabad   NaN          Sunrisers Hyderabad
# 1      2    2017            Pune   NaN               Mumbai Indians
# 2      3    2017          Rajkot   NaN                Gujarat Lions
# 3      4    2017          Indore   NaN       Rising Pune Supergiant
# 4      5    2017       Bangalore   NaN  Royal Challengers Bangalore
# 6      7    2017          Mumbai   NaN        Kolkata Knight Riders
# 10    11    2017         Kolkata   NaN              Kings XI Punjab
# 14    15    2017           Delhi   NaN             Delhi Daredevils
# 31    32    2017      Chandigarh   NaN          Sunrisers Hyderabad
# 48    49    2017          Kanpur   NaN                Gujarat Lions
# 64    65    2008          Jaipur   NaN              Kings XI Punjab
# 66    67    2008         Chennai   NaN          Chennai Super Kings
# 117  118    2009       Cape Town   NaN               Mumbai Indians
# ...

# %%
data.dropna(axis=1)  #delete column null values
# Out:
#       id  season                        team1                        team2  \
# 0      1    2017          Sunrisers Hyderabad  Royal Challengers Bangalore
# 1      2    2017               Mumbai Indians       Rising Pune Supergiant
# 2      3    2017                Gujarat Lions        Kolkata Knight Riders
# 3      4    2017       Rising Pune Supergiant              Kings XI Punjab
# 4      5    2017  Royal Challengers Bangalore             Delhi Daredevils
# 6      7    2017        Kolkata Knight Riders               Mumbai Indians
# 10    11    2017              Kings XI Punjab        Kolkata Knight Riders
# 14    15    2017             Delhi Daredevils              Kings XI Punjab
# 31    32    2017          Sunrisers Hyderabad              Kings XI Punjab
# 48    49    2017                Gujarat Lions             Delhi Daredevils
# 64    65    2008              Kings XI Punjab             Rajasthan Royals
# ...

# %%
data.dropna(axis=1,how="all")
# Out:
#       id  season            city                        team1  \
# 0      1    2017       Hyderabad          Sunrisers Hyderabad
# 1      2    2017            Pune               Mumbai Indians
# 2      3    2017          Rajkot                Gujarat Lions
# 3      4    2017          Indore       Rising Pune Supergiant
# 4      5    2017       Bangalore  Royal Challengers Bangalore
# 6      7    2017          Mumbai        Kolkata Knight Riders
# 10    11    2017         Kolkata              Kings XI Punjab
# 14    15    2017           Delhi             Delhi Daredevils
# 31    32    2017      Chandigarh          Sunrisers Hyderabad
# 48    49    2017          Kanpur                Gujarat Lions
# 64    65    2008          Jaipur              Kings XI Punjab
# 66    67    2008         Chennai          Chennai Super Kings
# 117  118    2009       Cape Town               Mumbai Indians
# 121  122    2009  Port Elizabeth          Chennai Super Kings
# ...

# %%
data.dropna(axis=1,how="all").shape
# Out:
# (31, 16)

# %%
data.dropna(subset=["city"]).shape     # show missing values
# Out:
# (30, 18)

# %%
data.dropna(subset=["city",'team2']).shape
# Out:
# (30, 18)

# %% [markdown]
# # filling missing values by using fillna()

# %%
data.fillna(0)             replace NAN to zero
# Out:
#       id  season            city  date                        team1  \
# 0      1    2017       Hyderabad   0.0          Sunrisers Hyderabad
# 1      2    2017            Pune   0.0               Mumbai Indians
# 2      3    2017          Rajkot   0.0                Gujarat Lions
# 3      4    2017          Indore   0.0       Rising Pune Supergiant
# 4      5    2017       Bangalore   0.0  Royal Challengers Bangalore
# 6      7    2017          Mumbai   0.0        Kolkata Knight Riders
# 10    11    2017         Kolkata   0.0              Kings XI Punjab
# 14    15    2017           Delhi   0.0             Delhi Daredevils
# 31    32    2017      Chandigarh   0.0          Sunrisers Hyderabad
# 48    49    2017          Kanpur   0.0                Gujarat Lions
# 64    65    2008          Jaipur   0.0              Kings XI Punjab
# 66    67    2008         Chennai   0.0          Chennai Super Kings
# 117  118    2009       Cape Town   0.0               Mumbai Indians
# ...

# %%
# data_filled = data.fillna('New Value')
print(data_filled)

# %% [markdown]
# # replace() method is used to replace the value '2017' in the 'season' column with 'New Value'.

# %%
data['season'] = data['season'].replace(2017, 00)
data.head()
# Out:
#    id  season       city  date                        team1  \
# 0   1       0  Hyderabad   NaN          Sunrisers Hyderabad
# 1   2       0       Pune   NaN               Mumbai Indians
# 2   3       0     Rajkot   NaN                Gujarat Lions
# 3   4       0     Indore   NaN       Rising Pune Supergiant
# 4   5       0  Bangalore   NaN  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0          Sunrisers Hyderabad           35
# ...

# %%
data['team1'] = data['team1'].replace("Sunrisers Hyderabad", "fsd")
data.head()
# Out:
#    id  season       city  date                        team1  \
# 0   1       0  Hyderabad   NaN                          fsd
# 1   2       0       Pune   NaN               Mumbai Indians
# 2   3       0     Rajkot   NaN                Gujarat Lions
# 3   4       0     Indore   NaN       Rising Pune Supergiant
# 4   5       0  Bangalore   NaN  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0          Sunrisers Hyderabad           35
# ...

# %%
data['win_by_wickets'] = data['win_by_wickets'].replace(10,"NaN")
data.head()
# Out:
#    id  season       city  date                        team1  \
# 0   1       0  Hyderabad   NaN                          fsd
# 1   2       0       Pune   NaN               Mumbai Indians
# 2   3       0     Rajkot   NaN                Gujarat Lions
# 3   4       0     Indore   NaN       Rising Pune Supergiant
# 4   5       0  Bangalore   NaN  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0          Sunrisers Hyderabad           35
# ...

# %%
data['win_by_wickets'] = data['win_by_wickets'].replace('nan',"NaN")
data.head()
# Out:
#    id  season       city  date                        team1  \
# 0   1       0  Hyderabad   NaN                          fsd
# 1   2       0       Pune   NaN               Mumbai Indians
# 2   3       0     Rajkot   NaN                Gujarat Lions
# 3   4       0     Indore   NaN       Rising Pune Supergiant
# 4   5       0  Bangalore   NaN  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0          Sunrisers Hyderabad           35
# ...

# %%
data['win_by_wickets'].fillna(method='bfill').head(5)            # not working>>>back value
# Out:
# 0      0
# 1      7
# 2    NaN
# 3      6
# 4      0
# Name: win_by_wickets, dtype: object

# %%
data['win_by_wickets'].fillna(method='ffill').head(5)          #not working front value
# Out:
# 0      0
# 1      7
# 2    NaN
# 3      6
# 4      0
# Name: win_by_wickets, dtype: object

# %%
import matplotlib.pyplot as plt

# %%
data['venue'].value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
data['win_by_runs'].value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
data['win_by_runs'].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='win_by_runs'>

# %%
data['venue'].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='venue'>

# %%
data['win_by_runs'].value_counts().plot(kind="barh")
# Out:
# <Axes: >

# %%
data['win_by_runs'].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>
